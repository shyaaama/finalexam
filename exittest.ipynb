# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv('/content/Coupen.csv')

# %% [markdown]
# first 5 rows

# %%
df.head()
# Out:
#        destination  passanger weather  temperature  time  \
# 0  No Urgent Place      Alone   Sunny           55   2PM
# 1  No Urgent Place  Friend(s)   Sunny           80  10AM
# 2  No Urgent Place  Friend(s)   Sunny           80  10AM
# 3  No Urgent Place  Friend(s)   Sunny           80   2PM
# 4  No Urgent Place  Friend(s)   Sunny           80   2PM
#
#                   coupon expiration  gender age      maritalStatus  ...  \
# 0        Restaurant(<20)         1d  Female  21  Unmarried partner  ...
# 1           Coffee House         2h  Female  21  Unmarried partner  ...
# 2  Carry out & Take away         2h  Female  21  Unmarried partner  ...
# 3           Coffee House         2h  Female  21  Unmarried partner  ...
# 4           Coffee House         1d  Female  21  Unmarried partner  ...
#
#    CoffeeHouse CarryAway RestaurantLessThan20 Restaurant20To50  \
# 0        never       NaN                  4~8              1~3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12684 entries, 0 to 12683
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   destination           12681 non-null  object
#  1   passanger             12679 non-null  object
#  2   weather               12684 non-null  object
#  3   temperature           12684 non-null  int64
#  4   time                  12684 non-null  object
#  5   coupon                12684 non-null  object
#  6   expiration            12681 non-null  object
#  7   gender                12684 non-null  object
#  8   age                   12684 non-null  object
#  9   maritalStatus         12681 non-null  object
#  10  has_children          12684 non-null  int64
#  11  education             12684 non-null  object
#  12  occupation            12684 non-null  object
#  13  income                12684 non-null  object
#  14  car                   108 non-null    object
# ...

# %% [markdown]
# there are object values and int values

# %%
df.describe()
# Out:
#         temperature  has_children  toCoupon_GEQ5min  toCoupon_GEQ15min  \
# count  12684.000000  12684.000000           12684.0       12684.000000
# mean      63.301798      0.414144               1.0           0.561495
# std       19.154486      0.492593               0.0           0.496224
# min       30.000000      0.000000               1.0           0.000000
# 25%       55.000000      0.000000               1.0           0.000000
# 50%       80.000000      0.000000               1.0           1.000000
# 75%       80.000000      1.000000               1.0           1.000000
# max       80.000000      1.000000               1.0           1.000000
#
#        toCoupon_GEQ25min  direction_same  direction_opp             Y
# count       12684.000000    12684.000000   12684.000000  12684.000000
# mean            0.119126        0.214759       0.785241      0.568433
# std             0.323950        0.410671       0.410671      0.495314
# ...

# %%
df.isnull().sum()
# Out:
# destination                 3
# passanger                   5
# weather                     0
# temperature                 0
# time                        0
# coupon                      0
# expiration                  3
# gender                      0
# age                         0
# maritalStatus               3
# has_children                0
# education                   0
# occupation                  0
# income                      0
# car                     12576
# Bar                       107
# CoffeeHouse               217
# CarryAway                 153
# RestaurantLessThan20      130
# Restaurant20To50          189
# toCoupon_GEQ5min            0
# toCoupon_GEQ15min           0
# toCoupon_GEQ25min           0
# direction_same              0
# direction_opp               0
# Y                           0
# dtype: int64

# %% [markdown]
# there are null values

# %% [markdown]
# univariate analysis

# %%
print(df['destination'].value_counts())
# Out:
# destination
# No Urgent Place    6281
# Home               3237
# Work               3163
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))
plt.bar(df['destination'].value_counts().index, df['destination'].value_counts())
plt.xlabel('Destination')
plt.ylabel('Count')
plt.title('Destination Distribution')
plt.show()

# %% [markdown]
# home and work count are aproximately equal.no urgent place is high count in designation.

# %%
plt.figure(figsize=(8,6))
plt.bar(df['passanger'].value_counts().index, df['passanger'].value_counts())
plt.xlabel('Passanger')
plt.ylabel('Count')
plt.title('Passanger Distribution')
plt.show()

# %% [markdown]
# alone are high in count.

# %%
plt.figure(figsize=(8,6))
plt.bar(df['weather'].value_counts().index, df['weather'].value_counts())
plt.xlabel('Weather')
plt.ylabel('Count')
plt.title('Weather Distribution')
plt.show()

# %% [markdown]
# most common weather is sunny

# %%
plt.figure(figsize=(8,6))
plt.hist(df['temperature'], bins=10)
plt.xlabel('Temperature')
plt.ylabel('Count')
plt.title('Temperature Distribution')
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.hist(df['time'], bins=10)
plt.xlabel('Time')
plt.ylabel('Count')
plt.title('Time Distribution')
plt.show()

# %% [markdown]
# the passengers are high at 6 to 7

# %% [markdown]
# destination v/s passenger

# %%
plt.figure(figsize=(8,6))
plt.bar(df['income'].value_counts().index, df['income'].value_counts())
plt.xlabel('Income')
plt.ylabel('Count')
plt.title('Income Distribution')
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.bar(df['occupation'].value_counts().index, df['occupation'].value_counts())
plt.xlabel('Occupation')
plt.ylabel('Count')
plt.title('Occupation Distribution')
plt.show()

# %% [markdown]
# bivariate

# %%
destination_order = df['destination'].unique()
passenger_order = df['passanger'].unique()
time_order = df['time'].unique()

fig, axes = plt.subplots(2, 2, figsize=(15, 10))


sns.countplot(x='destination', hue='passanger', data=df[df['Y'] == 0], ax=axes[0, 0], order=destination_order, hue_order=passenger_order)
axes[0, 0].set_title('destination vs passenger (count), Y=0')
axes[0, 0].legend().remove()



sns.countplot(x='destination', hue='passanger', data=df[df['Y'] == 1], ax=axes[0, 1], order=destination_order, hue_order=passenger_order)
axes[0, 1].set_title('destination vs passenger (count), Y=1')

axes[0, 1].legend(loc='center left', bbox_to_anchor=(1, 0.5))


sns.countplot(x='destination', hue='time', data=df[df['Y'] == 0], ax=axes[1, 0], order=destination_order, hue_order=time_order)
axes[1, 0].set_title('destination vs time (count), Y=0')
axes[1, 0].legend().remove()



sns.countplot(x='destination', hue='time', data=df[df['Y'] == 1], ax=axes[1, 1], order=destination_order, hue_order=time_order)
axes[1, 1].set_title('destination vs time (count), Y=1')


axes[1, 1].legend(loc='center left', bbox_to_anchor=(1, 0.5))

fig.tight_layout()
plt.show()

# %% [markdown]
# Maximum users accept coupons when the time is 2 PM and 10 AM, the destination is No Urgent Place, and the co-passanger is Friends.

# %%
plt.figure(figsize=(10, 5))
sns.barplot(x='gender', y='Y', data=df, ci=None)
plt.title('Likelihood of Accepting a Coupon by Gender')
plt.ylabel('Acceptance Rate')
plt.show()
# Out:
# <ipython-input-126-0ef7c1179c7c>:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='gender', y='Y', data=df, ci=None)

# %% [markdown]
# male count is higher

# %%
sns.pairplot(df, hue='Y', diag_kind='kde')
plt.show()

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
key = ['temperature','has_children','RestaurantLessThan20','Restaurant20To50',
                  'toCoupon_GEQ5min','toCoupon_GEQ15min', 'toCoupon_GEQ25min','direction_same','direction_opp']


plt.figure(figsize=(20, 15))
for i, r in enumerate(key, 1):
    plt.subplot(4, 3, i)
    sns.scatterplot(x=df[r], y=df['Y'])
    plt.title(f'Y vs {r}')
    plt.xlabel(r)
    plt.ylabel('Y')
plt.tight_layout(pad=3.0)  # Adjust the padding between plots
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12684 entries, 0 to 12683
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   destination           12681 non-null  object
#  1   passanger             12679 non-null  object
#  2   weather               12684 non-null  object
#  3   temperature           12684 non-null  int64
#  4   time                  12684 non-null  object
#  5   coupon                12684 non-null  object
#  6   expiration            12681 non-null  object
#  7   gender                12684 non-null  object
#  8   age                   12684 non-null  object
#  9   maritalStatus         12681 non-null  object
#  10  has_children          12684 non-null  int64
#  11  education             12684 non-null  object
#  12  occupation            12684 non-null  object
#  13  income                12684 non-null  object
#  14  car                   108 non-null    object
# ...

# %%
num=df.select_dtypes(include=[np.number])

# %%
corr=num.corr()
plt.figure(figsize=(12, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm', linewidths=0.5)
# Out:
# <Axes: >

# %% [markdown]
# temperature has high correlation with Y

# %%
df = df.drop_duplicates()

# %%
df.isnull().sum()
# Out:
# destination                 3
# passanger                   5
# weather                     0
# temperature                 0
# time                        0
# coupon                      0
# expiration                  3
# gender                      0
# age                         0
# maritalStatus               3
# has_children                0
# education                   0
# occupation                  0
# income                      0
# car                     12502
# Bar                       107
# CoffeeHouse               217
# CarryAway                 152
# RestaurantLessThan20      129
# Restaurant20To50          189
# toCoupon_GEQ5min            0
# toCoupon_GEQ15min           0
# toCoupon_GEQ25min           0
# direction_same              0
# direction_opp               0
# Y                           0
# dtype: int64

# %%
for i in df.columns:
  missing_perc=(df[i].isnull().sum()/len(df))*100
  print(f'{i}: {missing_perc:.2f}%')
# Out:
# destination: 0.02%
# passanger: 0.04%
# weather: 0.00%
# temperature: 0.00%
# time: 0.00%
# coupon: 0.00%
# expiration: 0.02%
# gender: 0.00%
# age: 0.00%
# maritalStatus: 0.02%
# has_children: 0.00%
# education: 0.00%
# occupation: 0.00%
# income: 0.00%
# car: 99.14%
# Bar: 0.85%
# CoffeeHouse: 1.72%
# CarryAway: 1.21%
# RestaurantLessThan20: 1.02%
# Restaurant20To50: 1.50%
# toCoupon_GEQ5min: 0.00%
# toCoupon_GEQ15min: 0.00%
# toCoupon_GEQ25min: 0.00%
# direction_same: 0.00%
# direction_opp: 0.00%
# Y: 0.00%

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12610 entries, 0 to 12683
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   destination           12607 non-null  object
#  1   passanger             12605 non-null  object
#  2   weather               12610 non-null  object
#  3   temperature           12610 non-null  int64
#  4   time                  12610 non-null  object
#  5   coupon                12610 non-null  object
#  6   expiration            12607 non-null  object
#  7   gender                12610 non-null  object
#  8   age                   12610 non-null  object
#  9   maritalStatus         12607 non-null  object
#  10  has_children          12610 non-null  int64
#  11  education             12610 non-null  object
#  12  occupation            12610 non-null  object
#  13  income                12610 non-null  object
#  14  car                   108 non-null    object
# ...

# %% [markdown]
# the categorical null values are imputed with mode

# %%
from sklearn.impute import SimpleImputer
object_columns = ['destination','passanger','expiration','maritalStatus','Bar','CoffeeHouse','CarryAway',
                  'RestaurantLessThan20','Restaurant20To50']
imputer = SimpleImputer(strategy='most_frequent')
df[object_columns] = imputer.fit_transform(df[object_columns])

# %%
df.isnull().sum()
# Out:
# destination                 0
# passanger                   0
# weather                     0
# temperature                 0
# time                        0
# coupon                      0
# expiration                  0
# gender                      0
# age                         0
# maritalStatus               0
# has_children                0
# education                   0
# occupation                  0
# income                      0
# car                     12502
# Bar                         0
# CoffeeHouse                 0
# CarryAway                   0
# RestaurantLessThan20        0
# Restaurant20To50            0
# toCoupon_GEQ5min            0
# toCoupon_GEQ15min           0
# toCoupon_GEQ25min           0
# direction_same              0
# direction_opp               0
# Y                           0
# dtype: int64

# %% [markdown]
# as car have 99% null value remove the column

# %%
df=df.drop(['car'],axis=1)

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df = df.drop_duplicates()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12609 entries, 0 to 12683
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   destination           12609 non-null  object
#  1   passanger             12609 non-null  object
#  2   weather               12609 non-null  object
#  3   temperature           12609 non-null  int64
#  4   time                  12609 non-null  object
#  5   coupon                12609 non-null  object
#  6   expiration            12609 non-null  object
#  7   gender                12609 non-null  object
#  8   age                   12609 non-null  object
#  9   maritalStatus         12609 non-null  object
#  10  has_children          12609 non-null  int64
#  11  education             12609 non-null  object
#  12  occupation            12609 non-null  object
#  13  income                12609 non-null  object
#  14  Bar                   12609 non-null  object
# ...

# %% [markdown]
# converting categorical to numerical

# %%
df['destination_encoded'] = le.fit_transform(df['destination'])
df['passanger_encoded'] = le.fit_transform(df['passanger'])
df['weather_encoded'] = le.fit_transform(df['weather'])
df['time_encoded'] = le.fit_transform(df['time'])
df['coupon_encoded'] = le.fit_transform(df['coupon'])
df['expiration_encoded'] = le.fit_transform(df['expiration'])
df['gender_encoded'] = le.fit_transform(df['gender'])
df['age_encoded'] = le.fit_transform(df['age'])
df['maritalStatus_encoded'] = le.fit_transform(df['maritalStatus'])
df['education_encoded'] = le.fit_transform(df['education'])
df['occupation_encoded'] = le.fit_transform(df['occupation'])
df['income_encoded'] = le.fit_transform(df['income'])
df['Bar_encoded'] = le.fit_transform(df['Bar'])
df['CoffeeHouse_encoded'] = le.fit_transform(df['CoffeeHouse'])
df['CarryAway_encoded'] = le.fit_transform(df['CarryAway'])
df['RestaurantLessThan20_encoded'] = le.fit_transform(df['RestaurantLessThan20'])
df['Restaurant20To50_encoded'] = le.fit_transform(df['Restaurant20To50'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12609 entries, 0 to 12683
# Data columns (total 42 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   destination                   12609 non-null  object
#  1   passanger                     12609 non-null  object
#  2   weather                       12609 non-null  object
#  3   temperature                   12609 non-null  int64
#  4   time                          12609 non-null  object
#  5   coupon                        12609 non-null  object
#  6   expiration                    12609 non-null  object
#  7   gender                        12609 non-null  object
#  8   age                           12609 non-null  object
#  9   maritalStatus                 12609 non-null  object
#  10  has_children                  12609 non-null  int64
#  11  education                     12609 non-null  object
# ...

# %%
object_cols = df.select_dtypes(['object']).columns
df = df.drop(object_cols, axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12609 entries, 0 to 12683
# Data columns (total 25 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   temperature                   12609 non-null  int64
#  1   has_children                  12609 non-null  int64
#  2   toCoupon_GEQ5min              12609 non-null  int64
#  3   toCoupon_GEQ15min             12609 non-null  int64
#  4   toCoupon_GEQ25min             12609 non-null  int64
#  5   direction_same                12609 non-null  int64
#  6   direction_opp                 12609 non-null  int64
#  7   Y                             12609 non-null  int64
#  8   destination_encoded           12609 non-null  int64
#  9   passanger_encoded             12609 non-null  int64
#  10  weather_encoded               12609 non-null  int64
#  11  time_encoded                  12609 non-null  int64
#  12  coupon_encoded                12609 non-null  int64
# ...

# %%
df
# Out:
#        temperature  has_children  toCoupon_GEQ5min  toCoupon_GEQ15min  \
# 0               55             1                 1                  0
# 1               80             1                 1                  0
# 2               80             1                 1                  1
# 3               80             1                 1                  1
# 4               80             1                 1                  1
# ...            ...           ...               ...                ...
# 12679           55             0                 1                  0
# 12680           55             0                 1                  0
# 12681           30             0                 1                  0
# 12682           30             0                 1                  1
# 12683           80             0                 1                  0
#
#        toCoupon_GEQ25min  direction_same  direction_opp  Y  \
# 0                      0               0              1  1
# ...

# %%
y=df['Y']

# %% [markdown]
# feature selection

# %%
from sklearn.feature_selection import SelectKBest, f_classif

# Select the top 10 features according to the ANOVA F-value
selector = SelectKBest(f_classif, k=10)
selector.fit_transform(df.drop('Y', axis=1), df['Y'])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_selection/_univariate_selection.py:112: UserWarning: Features [2] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_selection/_univariate_selection.py:113: RuntimeWarning: invalid value encountered in divide
#   f = msb / msw
# array([[55,  0,  0, ...,  4,  4,  0],
#        [80,  0,  0, ...,  4,  4,  0],
#        [80,  1,  0, ...,  4,  4,  0],
#        ...,
#        [30,  0,  0, ...,  4,  4,  0],
#        [30,  1,  1, ...,  4,  4,  0],
#        [80,  0,  0, ...,  4,  4,  0]])

# %%
selected_indices = selector.get_support(indices=True)
selected_features = df.columns[selected_indices]

# %%
selected_features
# Out:
# Index(['temperature', 'toCoupon_GEQ15min', 'toCoupon_GEQ25min',
#        'destination_encoded', 'passanger_encoded', 'time_encoded',
#        'coupon_encoded', 'income_encoded', 'Bar_encoded',
#        'RestaurantLessThan20_encoded'],
#       dtype='object')

# %%
df =df.iloc[:,selected_indices]

# %%
df.columns
# Out:
# Index(['temperature', 'toCoupon_GEQ15min', 'toCoupon_GEQ25min',
#        'destination_encoded', 'passanger_encoded', 'time_encoded',
#        'coupon_encoded', 'income_encoded', 'Bar_encoded',
#        'RestaurantLessThan20_encoded'],
#       dtype='object')

# %%
df = pd.concat([df, y], axis=1)

# %%
df.columns
# Out:
# Index(['temperature', 'toCoupon_GEQ15min', 'toCoupon_GEQ25min',
#        'destination_encoded', 'passanger_encoded', 'time_encoded',
#        'coupon_encoded', 'income_encoded', 'Bar_encoded',
#        'RestaurantLessThan20_encoded', 'Y'],
#       dtype='object')

# %%
X = df.drop(['Y'], axis = 1)
y = df["Y"]

# %% [markdown]
# splitting

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size = .20, random_state=0)

# %% [markdown]
# **logistic regression**

# %%
from sklearn.linear_model import LogisticRegression

# %%
lgr=LogisticRegression()

# %%
lgr.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = lgr.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred, squared=False)

# %%
lgr.score(X_train,y_train)
# Out:
# 0.5815405968077724

# %%
lgr.score(X_test,y_test)
# Out:
# 0.6046788263283108

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.metrics import classification_report

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
rnd = RandomForestClassifier()

# %%
rnd.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=rnd.predict(X_test)

# %%
rnd.score(X_test,y_test)
# Out:
# 0.6403647898493259

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)


precision = precision_score(y_test, y_pred)
print("Precision:", precision)


recall = recall_score(y_test, y_pred)
print("Recall:", recall)


f1 = f1_score(y_test, y_pred)
print("F1-score:", f1)
# Out:
# Accuracy: 0.6403647898493259
# Precision: 0.6913161465400272
# Recall: 0.6927260367097213
# F1-score: 0.6920203735144312

# %% [markdown]
# SVC

# %%
from sklearn.svm import SVC


svm_clf = SVC(kernel='linear', C=1)
svm_clf.fit(X_train, y_train)

# Make predictions on the testing data
y_pred_svm = svm_clf.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred_svm)
print("Accuracy:", accuracy)


precision = precision_score(y_test, y_pred_svm)
print("Precision:", precision)


recall = recall_score(y_test, y_pred_svm)
print("Recall:", recall)


f1 = f1_score(y_test, y_pred_svm)
print("F1-score:", f1)
# Out:
# Accuracy: 0.6011102299762093
# Precision: 0.6052512449071978
# Recall: 0.9089055064581917
# F1-score: 0.7266304347826088

# %% [markdown]
# KNN

# %%
from sklearn.neighbors import KNeighborsClassifier


knn_clf = KNeighborsClassifier(n_neighbors=5)
knn_clf.fit(X_train, y_train)


y_pred = knn_clf.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)


precision = precision_score(y_test, y_pred)
print("Precision:", precision)


recall = recall_score(y_test, y_pred)
print("Recall:", recall)


f1 = f1_score(y_test, y_pred)
print("F1-score:", f1)
# Out:
# Accuracy: 0.6427438540840603
# Precision: 0.6917900403768507
# Recall: 0.698844323589395
# F1-score: 0.6952992898207644

# %%
from xgboost import XGBClassifier

xgb_clf = XGBClassifier()
xgb_clf.fit(X_train, y_train)


y_pred_xgb = xgb_clf.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred_xgb)
print("Accuracy:", accuracy)


precision = precision_score(y_test, y_pred_xgb)
print("Precision:", precision)


recall = recall_score(y_test, y_pred_xgb)
print("Recall:", recall)


f1 = f1_score(y_test, y_pred_xgb)
print("F1-score:", f1)
# Out:
# Accuracy: 0.6946867565424266
# Precision: 0.7271548930654569
# Recall: 0.7627464309993202
# F1-score: 0.7445255474452556

# %% [markdown]
# Based on the results, XGBoost appears to be the best performer, with the highest accuracy, precision, recall, and F1-score

# %% [markdown]
# fine tuning

# %%
param_grid = {
    'max_depth': [3, 5, 7, 9, None],
    'learning_rate': [0.01, 0.1, 0.5, 1],
    'n_estimators': [50, 100, 200, 500],
    'gamma': [0, 0.1, 0.5, 1],
    'subsample': [0.5, 0.8, 1],
    'colsample_bytree': [0.5, 0.8, 1],
    'reg_alpha': [0, 0.1, 0.5, 1],
    'reg_lambda': [0, 0.1, 0.5, 1]
}

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
xgb_clf = XGBClassifier()

# %%
random_search_dtc =RandomizedSearchCV(xgb_clf,param_grid,n_iter=100, cv=5, n_jobs=-1, verbose=1, random_state=42)

# %%
random_search_dtc.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# RandomizedSearchCV(cv=5,
#                    estimator=XGBClassifier(base_score=None, booster=None,
#                                            callbacks=None,
#                                            colsample_bylevel=None,
#                                            colsample_bynode=None,
#                                            colsample_bytree=None, device=None,
#                                            early_stopping_rounds=None,
#                                            enable_categorical=False,
#                                            eval_metric=None, feature_types=None,
#                                            gamma=None, grow_policy=None,
#                                            importance_type=None,
#                                            interaction_constraints=None,
#                                            learning_rate...
# ...

# %%
print(f"Best parameters found: {random_search_dtc.best_params_}")
# Out:
# Best parameters found: {'subsample': 0.8, 'reg_lambda': 0, 'reg_alpha': 0.5, 'n_estimators': 500, 'max_depth': None, 'learning_rate': 0.1, 'gamma': 1, 'colsample_bytree': 0.5}

# %%
xgb=XGBClassifier(**{'subsample': 0.8, 'reg_lambda': 0, 'reg_alpha': 0.5, 'n_estimators': 500, 'max_depth': None, 'learning_rate': 0.1, 'gamma': 1, 'colsample_bytree': 0.5})

# %%
xgb.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.5, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=1, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=500, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
y_pred=xgb.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)


precision = precision_score(y_test, y_pred)
print("Precision:", precision)


recall = recall_score(y_test, y_pred)
print("Recall:", recall)


f1 = f1_score(y_test, y_pred)
print("F1-score:", f1)
# Out:
# Accuracy: 0.6934972244250595
# Precision: 0.7200504413619168
# Recall: 0.7763426240652618
# F1-score: 0.7471377167157344
